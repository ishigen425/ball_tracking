# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models
import os, sys, json
from model import TrackNet
from utils.get_dataloader import get_dataloader
import cv2
from PIL import Image

# %%
cuda0 = torch.device('cuda:0')
model = TrackNet().to(cuda0)

model.load_state_dict(torch.load('weight/epoch_0_1719'))
model.eval()


def open_image(path, shape):
    image = Image.open(path).convert("RGB")
    return np.asarray(image.resize(shape))

# %%
image3 = open_image('../data/DJI_0015/game_img_10692.jpg', (640,360))
image2 = open_image('../data/DJI_0015/game_img_10693.jpg', (640,360))
image1 = open_image('../data/DJI_0015/game_img_10694.jpg', (640,360))
image = np.dstack([image1, image2, image3])
print(image.shape)
image = torch.from_numpy(image).float().to(cuda0)
image = image.transpose(2, 0)
print(image.shape)
image = image[np.newaxis, :]
print(image.shape)
output = model(image) * 255
# Out:
# (360, 640, 9)
# torch.Size([9, 640, 360])
# torch.Size([1, 9, 640, 360])

# %%
import matplotlib.pyplot as plt
print(output.shape)
output_numpy = output.squeeze().cpu().detach().numpy().T
plt.imshow(output_numpy, cmap = "gray")
plt.show()
plt.imshow(image1)
plt.show()
# Out:
# torch.Size([1, 1, 640, 360])

# %%
cap = cv2.VideoCapture('../data/DJI_0016.MP4')
count = 0
while True:
    ret, frame = cap.read()
    if ret:
        image_numpy = cv2.resize(frame, (640, 360))
        image = torch.from_numpy(image_numpy).float().to(cuda0)
        image = image.transpose(2, 0)
        image = image[np.newaxis, :]
        output = model(image)
        output_numpy = output.squeeze().cpu().detach().numpy().T
        image_numpy = cv2.cvtColor(image_numpy, cv2.COLOR_RGB2GRAY)
        #output_numpy = cv2.cvtColor(output_numpy, cv2.COLOR_GRAY2RGB)
#         print(output_numpy.shape)
#         print(image_numpy.shape)
#         plt.imshow(output_numpy)
#         plt.show()
#         plt.imshow(image_numpy)
#         plt.show()

        write_image = cv2.addWeighted(src1=image_numpy,alpha=0.2,src2=output_numpy,beta=0.8,gamma=0, dtype=cv2.CV_32F)
        #write_image = cv2.bitwise_and(src1=image_numpy, src2=output_numpy)
        cv2.imwrite('output/{:05d}.jpg'.format(count), write_image)
    count += 1
    if count % 100 == 0:
        print(count)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-663bdb08cc18> in <module>
#       9         image = image[np.newaxis, :]
#      10         output = model(image)
# ---> 11         output_numpy = output.squeeze().cpu().detach().numpy().T
# ...
