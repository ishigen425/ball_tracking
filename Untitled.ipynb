# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np
import torchvision.models as models
from utils.generate_heatmap import gaussian, make_gaussian
import os, sys, json, cv2

# %%
def get_center(height, width, top, left):
    top -= height / 2
    left += width / 2
    return left, top

annotation_dir_path = '../data/tracking_data/vott-json-export/'
annotation_file_name = 'table-tenni-ball-tracking-export.json'

with open(os.path.join(annotation_dir_path, annotation_file_name)) as f:
    s = f.read()
    j = json.loads(s)

dataset = []
centers = []
# filepathとcenterだけ抽出してリスト化する
for idx, file_id in enumerate(j['assets']):
    asset = j['assets'][file_id]['asset']
    dataset.append([os.path.join(annotation_dir_path, asset['name']) + '.jpg'])
    regions = j['assets'][file_id]['regions']
    flg = False
    if regions:
        for info in regions:
            if 'ball' in info['tags']:
                bbox = info['boundingBox']
                dataset[idx].append(tuple((get_center(bbox['height'], bbox['width'], bbox['left'], bbox['top']))))
                flg = True
                
    if not flg:
        dataset[idx].append(tuple((None, None)))
dataset.sort()
dataset
# Out:
# [['../data/tracking_data/vott-json-export/DJI_0013.MP4#t=0.jpg.jpg',
#   (None, None)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=0.jpg.jpg',
#   (None, None)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.033333.jpg.jpg',
#   (490.4458064659746, 1308.9119739995697)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.066667.jpg.jpg',
#   (495.9913777111608, 1269.3739565323856)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.1.jpg.jpg',
#   (503.60718870346597, 1298.4971098265896)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.133333.jpg.jpg',
#   (500.8344030808729, 1252.7167630057804)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.166667.jpg.jpg',
#   (498.06161745827984, 1152.8323699421965)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.2.jpg.jpg',
#   (492.5240600443729, 1118.852389679966)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.233333.jpg.jpg',
#   (495.2888318356868, 1098.728323699422)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.266667.jpg.jpg',
#   (491.13855765877406, 973.1858689441777)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.3.jpg.jpg',
#   (488.3568677792041, 1000.2312138728323)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.333333.jpg.jpg',
#   (486.98026965058216, 924.6327365007754)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.366667.jpg.jpg',
#   (478.65211810012835, 864.2774566473988)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.4.jpg.jpg',
#   (484.2065936022914, 844.8617243093636)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.433333.jpg.jpg',
#   (478.66102235710525, 801.8568343882405)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.466667.jpg.jpg',
#   (466.87623824823584, 731.7985857071835)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.5.jpg.jpg',
#   (464.1016717742474, 733.1858689441777)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.533333.jpg.jpg',
#   (468.26352148523006, 696.4233083766798)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.566667.jpg.jpg',
#   (455.0905637136688, 635.3828459489341)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.6.jpg.jpg',
#   (453.70417090237225, 632.6082794749457)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.633333.jpg.jpg',
#   (451.6250268982763, 609.0226835946485)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.666667.jpg.jpg',
#   (446.0794556530902, 552.8381577092315)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.7.jpg.jpg',
#   (443.6528230204724, 554.0530322705114)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.733333.jpg.jpg',
#   (446.7730972715873, 583.3601697744996)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.766667.jpg.jpg',
#   (466.87267654544513, 683.2427819866881)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.8.jpg.jpg',
#   (467.5609756097561, 703.3526011560693)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.833333.jpg.jpg',
#   (477.96559988721276, 724.8630599479101)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.866667.jpg.jpg',
#   (502.22702887205327, 824.7456721600985)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.9.jpg.jpg',
#   (502.22702887205327, 826.1338458227904)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.933333.jpg.jpg',
#   (510.53915275994865, 890.635838150289)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.966667.jpg.jpg',
#   (539.6614156284551, 960.6994293855321)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=10.jpg.jpg',
#   (488.3568677792041, 1315.1445086705203)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=11.033333.jpg.jpg',
#   (550.753448544525, 997.4637708044254)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=11
],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.266667.jpg.jpg',
#   (674.1335044929397, 1253.4108498371263)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.3.jpg.jpg',
#   (672.7471116816431, 1258.2658959537573)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.333333.jpg.jpg',
#   (669.2815748662506, 1262.4277456647399)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.366667.jpg.jpg',
#   (664.428754813864, 1270.7514450867052)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.4.jpg.jpg',
#   (663.0423620025674, 1272.1387283236993)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.433333.jpg.jpg',
#   (664.428754813864, 1273.5260115606936)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.466667.jpg.jpg',
#   (658.8831835686779, 1272.1387283236993)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.5.jpg.jpg',
#   (656.1103979460847, 1270.7514450867052)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.533333.jpg.jpg',
#   (656.1103979460847, 1265.2023121387283)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.566667.jpg.jpg',
#   (650.5648267008986, 1281.849710982659)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.6.jpg.jpg',
#   (651.9512195121952, 1283.236994219653)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.633333.jpg.jpg',
#   (645.0192554557125, 1286.0115606936415)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.666667.jpg.jpg',
#   (649.178433889602, 1291.5606936416184)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.7.jpg.jpg',
#   (649.178433889602, 1294.3352601156068)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.733333.jpg.jpg',
#   (649.178433889602, 1294.3352601156068)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.766667.jpg.jpg',
#   (646.405648267009, 1301.271676300578)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.8.jpg.jpg',
#   (646.405648267009, 1301.271676300578)],
#  ['../data/tracking_data/vott-json-export/DJI_0013_30.MP4#t=62.833333.jpg.jpg',
#   (640.8600770218228, 1292.9479768786127)],
#  ...]

# %%
for image in trainset:
    center = image[1]
    x = y = 0
    if center[0] != None:
        print(center)
        x, y = center
        x = (x/1080) * 360
        y = (y/1920) * 640
    ht = make_gaussian(size=(360, 640), center=(x, y), is_ball=center[0] != None)
    plt.imshow(ht)
    plt.gray()
    plt.show()
# Out:
# (488.3568677792041, 1315.1445086705203)
# (490.4458064659746, 1308.9119739995697)
# (495.9913777111608, 1269.3739565323856)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-2dcdf138ea0b> in <module>
#       7         x = (x/1080) * 360
#       8         y = (y/1920) * 640
# ----> 9     ht = make_gaussian(size=(360, 640), center=(x, y), is_ball=center[0] != None)
#      10     plt.imshow(ht)
#      11     plt.gray()
#
# /home/tracking/utils/generate_heatmap.py in make_gaussian(size, center, is_ball)
#      23     for i in range(x):
#      24         for j in range(y):
# ---> 25             heatmap[i, j] = gaussian(i, j, *center)
#      26     return heatmap
#
# /home/tracking/utils/generate_heatmap.py in gaussian(x, y, x0, y0, sigma)
#       3 def gaussian(x, y, x0, y0, sigma=10):
#       4     sigma_d = sigma ** 2
# ----> 5     t0 = np.exp(-((x-x0) ** 2 + (y-y0) ** 2) / (2 * sigma_d))
#       6     first = t0 / (2 * np.pi * sigma_d)
#       7     second = 2 * np.pi * sigma_d * 255
#
# KeyboardInterrupt:

# %%
class TrackNet(nn.Module):
    def __init__(self):
        super(TrackNet, self).__init__()
        self.vgg = self.make_vgg()
        self.deconv = self.make_deconv()
        
    def make_vgg(self):
        channels = [9, 64, 64, 128, 128, 128, 256, 256, 256, 512, 512, 512]
        layers = []
        for i in range(len(channels)-1):
            layers.append(nn.Conv2d(
                in_channels=channels[i], out_channels=channels[i+1], kernel_size=3,
                stride=1, padding=1
            ))
            layers.append(nn.BatchNorm2d(
                channels[i+1], eps=1e-5, momentum=0.1, affine=True, track_running_stats=True
            ))
            layers.append(nn.ReLU(inplace=True))
            if i in [2, 6, 9]:
                layers.append(nn.MaxPool2d(
                    kernel_size=2, stride=2, padding=0, dilation=1,
                    ceil_mode=False, return_indices=True
                ))
        return nn.Sequential(*layers)
    
    def make_deconv(self):
        channels = [512, 512, 512, 512, 256, 256, 256, 128, 128, 128, 64, 64, 256]
        layers = []
        for i in range(len(channels)-1):
            if i in [0, 4, 7]:
                layers.append(nn.MaxUnpool2d(kernel_size=2))
            layers.append(nn.ConvTranspose2d(
                in_channels=channels[i], out_channels=channels[i+1], kernel_size=3,
                stride=1, padding=1
            ))
            layers.append(nn.BatchNorm2d(
                channels[i+1], eps=1e-5, momentum=0.1, affine=True, track_running_stats=True
            ))
            layers.append(nn.ReLU(inplace=True))
        return nn.Sequential(*layers)
    
    def forward(self, x):
        indices_list = []
        cnt = 0
        for layer in self.vgg:
            print(cnt)
            cnt += 1
            print(x.shape)
            if isinstance(layer, nn.MaxPool2d):
                x, indices = layer(x)
                indices_list.append(indices)
            else:
                x = layer(x)
        print([i.shape for i in indices_list])
        for layer in self.deconv:
            cnt += 1
            print(x.shape)
            if isinstance(layer, nn.MaxUnpool2d):
                print(layer)
                indices = indices_list.pop()
                x = layer(x, indices)
            else:
                x = layer(x)
        x = F.softmax(x, dim=1)
        print(x.shape)
        return x

# %%
cuda0 = torch.device('cuda:0')
net = TrackNet().to(cuda0)
from PIL import Image
import cv2
import numpy as np
import torch.optim as optim


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

for epoch in range(2):  # loop over the dataset multiple times

    running_loss = 0.0
    for i in range(2):
        # get the inputs; data is a list of [inputs, labels]
#         path, center = trainset[i]
#         path1, center = trainset[i+1]
#         path2, center = trainset[i+2]
#         x = y = 0
#         if center[0] != None:
#             print(center)
#             x, y = center
#             x = (x/1080) * 360
#             y = (y/1920) * 640
#         target = make_gaussian(size=(360, 640), center=(x, y), is_ball=center[0] != None)
        
#         inputs1 = np.array(cv2.imread(path))
#         inputs2 = np.array(cv2.imread(path))
#         inputs3 = np.array(cv2.imread(path))
#         inputs = torch.from_numpy(np.array([np.dstack([inputs1, inputs2, inputs3])]))
        inputs = torch.from_numpy(np.zeros((1, 9, 360, 640), dtype="float32")).to(cuda0)
        target = torch.from_numpy(np.zeros((360, 640))).to(cuda0)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0
# Out:
# 0
# torch.Size([1, 9, 360, 640])
# 1
# torch.Size([1, 64, 360, 640])
# 2
# torch.Size([1, 64, 360, 640])
# 3
# torch.Size([1, 64, 360, 640])
# 4
# torch.Size([1, 64, 360, 640])
# 5
# torch.Size([1, 64, 360, 640])
# 6
# torch.Size([1, 64, 360, 640])
# 7
# torch.Size([1, 128, 360, 640])
# 8
# torch.Size([1, 128, 360, 640])
# 9
# torch.Size([1, 128, 360, 640])
# 10
# torch.Size([1, 128, 180, 320])
# 11
# torch.Size([1, 128, 180, 320])
# 12
# torch.Size([1, 128, 180, 320])
# 13
# torch.Size([1, 128, 180, 320])
# 14
# torch.Size([1, 128, 180, 320])
# 15
# torch.Size([1, 128, 180, 320])
# 16
# torch.Size([1, 128, 180, 320])
# 17
# torch.Size([1, 256, 180, 320])
# 18
# torch.Size([1, 256, 180, 320])
# 19
# torch.Size([1, 256, 180, 320])
# 20
# torch.Size([1, 256, 180, 320])
# 21
# torch.Size([1, 256, 180, 320])
# 22
# torch.Size([1, 256, 180, 320])
# 23
# torch.Size([1, 256, 90, 160])
# 24
# torch.Size([1, 256, 90, 160])
# 25
# torch.Size([1, 256, 90, 160])
# 26
# torch.Size([1, 256, 90, 160])
# 27
# torch.Size([1, 512, 90, 160])
# 28
# torch.Size([1, 512, 90, 160])
# 29
# torch.Size([1, 512, 90, 160])
# 30
# torch.Size([1, 512, 90, 160])
# 31
# torch.Size([1, 512, 90, 160])
# 32
# torch.Size([1, 512, 90, 160])
# 33
# torch.Size([1, 512, 45, 80])
# 34
# torch.Size([1, 512, 45, 80])
# 35
# torch.Size([1, 512, 45, 80])
# [torch.Size([1, 128, 180, 320]), torch.Size([1, 256, 90, 160]), torch.Size([1, 512, 45, 80])]
# torch.Size([1, 512, 45, 80])
# MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 512, 90, 160])
# torch.Size([1, 256, 90, 160])
# torch.Size([1, 256, 90, 160])
# torch.Size([1, 256, 90, 160])
# MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
# torch.Size([1, 256, 180, 320])
# torch.Size([1, 256, 180, 320])
# torch.Size([1, 256, 180, 320])
# torch.Size([1, 256, 180, 320])
# torch.Size([1, 256, 180, 320])
# torch.Size([1, 256, 180, 320])
# torch.Size([1, 256, 180, 320])
# torch.Size([1, 128, 180, 320])
# torch.Size([1, 128, 180, 320])
# torch.Size([1, 128, 180, 320])
# MaxUnpool2d(kernel_size=(2, 2), stride=(2, 2), padding=(0, 0))
# torch.Size([1, 128, 360, 640])
# torch.Size([1, 128, 360, 640])
# torch.Size([1, 128, 360, 640])
# torch.Size([1, 128, 360, 640])
# torch.Size([1, 128, 360, 640])
# torch.Size([1, 128, 360, 640])
# torch.Size([1, 128, 360, 640])
# torch.Size([1, 64, 360, 640])
# torch.Size([1, 64, 360, 640])
# torch.Size([1, 64, 360, 640])
# torch.Size([1, 64, 360, 640])
# torch.Size([1, 64, 360, 640])
# torch.Size([1, 64, 360, 640])
# torch.Size([1, 256, 360, 640])
# torch.Size([1, 256, 360, 640])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-68eb7c04dcee> in <module>
#      37
#      38         # forward + backward + optimize
# ---> 39         outputs = net(inputs)
#      40         loss = criterion(outputs, target)
#      41         loss.backward()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-5-1542b02e194b> in forward(self, x)
#      62             else:
#      63                 x = layer(x)
# ---> 64         x = F.softmax(x, dim=1)
#      65         print(x.shape)
#      66         return x
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in softmax(input, dim, _stacklevel, dtype)
#    1186         dim = torch.jit._unwrap_optional(dim)
#    1187     if dtype is None:
# -> 1188         ret = input.softmax(dim)
#    1189     else:
#    1190         dtype = torch.jit._unwrap_optional(dtype)
#
# RuntimeError: CUDA out of memory. Tried to allocate 225.00 MiB (GPU 0; 7.79 GiB total capacity; 6.24 GiB already allocated; 56.56 MiB free; 31.18 MiB cached)

# %%
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import json
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

plt.ion()   # interactive mode

# %%
class BallDataset(Dataset):
    def __init__(self, json_file, root_dir, transform=None):
        with open(os.path.join(root_dir, json_file)) as f:
            s = f.read()
            j = json.loads(s)

        self.data_set = []
        # filepathとcenterだけ抽出してリスト化する
        for idx, file_id in enumerate(j['assets']):
            asset = j['assets'][file_id]['asset']
            self.data_set.append([os.path.join(root_dir, asset['name'])])
            regions = j['assets'][file_id]['regions']
            flg = False
            if regions:
                for info in regions:
                    if 'ball' in info['tags']:
                        bbox = info['boundingBox']
                        self.data_set[idx].append(tuple(self.get_center(bbox['height'], bbox['width'], bbox['left'], bbox['top'])))
                        flg = True

            if not flg:
                self.data_set[idx].append(tuple((None, None)))
        self.data_set.sort()
        self.root_dir = root_dir
        self.transform = transform
        
    def get_center(self, height, width, top, left):
        top -= height / 2
        left += width / 2
        return left, top

    def __len__(self):
        return len(self.data_set)
    
    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        output_size_w, output_size_h = (640, 360)
        img_name = self.data_set[idx][0]
        image = cv2.imread(img_name)
        center = self.data_set[idx][1]
        x = y = 0
        if center[0] != None:
            x, y = center
            x = (x/image.shape[0]) * output_size_h
            y = (y/image.shape[1]) * output_size_w
        heatmap = make_gaussian(size=(output_size_h, output_size_w), center=(x, y), is_ball=center[0] != None)
        image = cv2.resize(image, (output_size_w, output_size_h))
        data = {'image': image, 'target': heatmap}
        if self.transform:
            data = self.transform(data)
        return data

# %%
def show_landmarks(image, target):
    """Show image with landmarks"""
    plt.imshow(image)
    plt.show()
    plt.imshow(target)
    plt.show()
    plt.pause(0.001)

# %%
class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, sample):
        image, target = sample['image'], sample['target']

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        target = target.transpose((0, 1))
        return {'image': torch.from_numpy(image),
                'target': torch.from_numpy(target)}

# %%
ball_dataset = BallDataset(json_file='table-tenni-ball-tracking-export.json',
                           root_dir='../data/tracking_data/vott-json-export/',
                           transform=transforms.Compose([ToTensor()])
                          )

# %%
dataloader = DataLoader(ball_dataset, batch_size=4, shuffle=False, num_workers=0)
for i_batch, batched in enumerate(dataloader):
    print(i_batch, batched['image'].shape, batched['target'].shape)
# Out:
# 0 torch.Size([4, 3, 360, 640]) torch.Size([4, 360, 640])
# 1 torch.Size([4, 3, 360, 640]) torch.Size([4, 360, 640])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-6d5fd371c540> in <module>
#       1 dataloader = DataLoader(ball_dataset, batch_size=4, shuffle=False, num_workers=0)
# ----> 2 for i_batch, batched in enumerate(dataloader):
#       3     print(i_batch, batched['image'].shape, batched['target'].shape)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# <ipython-input-10-7dd1843b3cd1> in __getitem__(self, idx)
#      45             x = (x/image.shape[0]) * output_size_h
#      46             y = (y/image.shape[1]) * output_size_w
# ---> 47         heatmap = make_gaussian(size=(output_size_h, output_size_w), center=(x, y), is_ball=center[0] != None)
#      48         image = cv2.resize(image, (output_size_w, output_size_h))
#      49         data = {'image': image, 'target': heatmap}
#
# /home/tracking/utils/generate_heatmap.py in make_gaussian(size, center, is_ball)
#      25     for i in range(x):
#      26         for j in range(y):
# ---> 27             heatmap[i, j] = gaussian(i, j, *center)
#      28     return heatmap
#
# KeyboardInterrupt:

# %%
for i in batched['target'][0]:
    print(max(i))
# Out:
# tensor(6.4239e-62, dtype=torch.float64)
# tensor(3.4251e-61, dtype=torch.float64)
# tensor(1.8080e-60, dtype=torch.float64)
# tensor(9.4492e-60, dtype=torch.float64)
# tensor(4.8892e-59, dtype=torch.float64)
# tensor(2.5046e-58, dtype=torch.float64)
# tensor(1.2703e-57, dtype=torch.float64)
# tensor(6.3785e-57, dtype=torch.float64)
# tensor(3.1710e-56, dtype=torch.float64)
# tensor(1.5607e-55, dtype=torch.float64)
# tensor(7.6052e-55, dtype=torch.float64)
# tensor(3.6691e-54, dtype=torch.float64)
# tensor(1.7525e-53, dtype=torch.float64)
# tensor(8.2874e-53, dtype=torch.float64)
# tensor(3.8800e-52, dtype=torch.float64)
# tensor(1.7985e-51, dtype=torch.float64)
# tensor(8.2535e-51, dtype=torch.float64)
# tensor(3.7500e-50, dtype=torch.float64)
# tensor(1.6868e-49, dtype=torch.float64)
# tensor(7.5123e-49, dtype=torch.float64)
# tensor(3.3123e-48, dtype=torch.float64)
# tensor(1.4459e-47, dtype=torch.float64)
# tensor(6.2491e-47, dtype=torch.float64)
# tensor(2.6739e-46, dtype=torch.float64)
# tensor(1.1328e-45, dtype=torch.float64)
# tensor(4.7509e-45, dtype=torch.float64)
# tensor(1.9728e-44, dtype=torch.float64)
# tensor(8.1103e-44, dtype=torch.float64)
# tensor(3.3011e-43, dtype=torch.float64)
# tensor(1.3302e-42, dtype=torch.float64)
# tensor(5.3071e-42, dtype=torch.float64)
# tensor(2.0962e-41, dtype=torch.float64)
# tensor(8.1976e-41, dtype=torch.float64)
# tensor(3.1738e-40, dtype=torch.float64)
# tensor(1.2166e-39, dtype=torch.float64)
# tensor(4.6170e-39, dtype=torch.float64)
# tensor(1.7347e-38, dtype=torch.float64)
# tensor(6.4529e-38, dtype=torch.float64)
# tensor(2.3765e-37, dtype=torch.float64)
# tensor(8.6653e-37, dtype=torch.float64)
# tensor(3.1281e-36, dtype=torch.float64)
# tensor(1.1180e-35, dtype=torch.float64)
# tensor(3.9560e-35, dtype=torch.float64)
# tensor(1.3859e-34, dtype=torch.float64)
# tensor(4.8068e-34, dtype=torch.float64)
# tensor(1.6506e-33, dtype=torch.float64)
# tensor(5.6115e-33, dtype=torch.float64)
# tensor(1.8888e-32, dtype=torch.float64)
# tensor(6.2942e-32, dtype=torch.float64)
# tensor(2.0766e-31, dtype=torch.float64)
# tensor(6.7830e-31, dtype=torch.float64)
# tensor(2.1936e-30, dtype=torch.float64)
# tensor(7.0232e-30, dtype=torch.float64)
# tensor(2.2263e-29, dtype=torch.float64)
# tensor(6.9867e-29, dtype=torch.float64)
# tensor(2.1708e-28, dtype=torch.float64)
# tensor(6.6779e-28, dtype=torch.float64)
# tensor(2.0338e-27, dtype=torch.float64)
# tensor(6.1325e-27, dtype=torch.float64)
# tensor(1.8307e-26, dtype=torch.float64)
# tensor(5.4108e-26, dtype=torch.float64)
# tensor(1.5833e-25, dtype=torch.float64)
# tensor(4.5869e-25, dtype=torch.float64)
# tensor(1.3156e-24, dtype=torch.float64)
# tensor(3.7359e-24, dtype=torch.float64)
# tensor(1.0503e-23, dtype=torch.float64)
# tensor(2.9235e-23, dtype=torch.float64)
# tensor(8.0565e-23, dtype=torch.float64)
# tensor(2.1981e-22, dtype=torch.float64)
# tensor(5.9374e-22, dtype=torch.float64)
# tensor(1.5878e-21, dtype=torch.float64)
# tensor(4.2041e-21, dtype=torch.float64)
# tensor(1.1021e-20, dtype=torch.float64)
# tensor(2.8601e-20, dtype=torch.float64)
# tensor(7.3489e-20, dtype=torch.float64)
# tensor(1.8695e-19, dtype=torch.float64)
# tensor(4.7084e-19, dtype=torch.float64)
# tensor(1.1740e-18, dtype=torch.float64)
# tensor(2.8984e-18, dtype=torch.float64)
# tensor(7.0840e-18, dtype=torch.float64)
# tensor(1.7142e-17, dtype=torch.float64)
# tensor(4.1068e-17, dtype=torch.float64)
# tensor(9.7408e-17, dtype=torch.float64)
# tensor(2.2874e-16, dtype=torch.float64)
# tensor(5.3181e-16, dtype=torch.float64)
# tensor(1.2241e-15, dtype=torch.float64)
# tensor(2.7897e-15, dtype=torch.float64)
# tensor(6.2941e-15, dtype=torch.float64)
# tensor(1.4060e-14, dtype=torch.float64)
# tensor(3.1093e-14, dtype=torch.float64)
# tensor(6.8080e-14, dtype=torch.float64)
# tensor(1.4758e-13, dtype=torch.float64)
# tensor(3.1673e-13, dtype=torch.float64)
# tensor(6.7301e-13, dtype=torch.float64)
# tensor(1.4158e-12, dtype=torch.float64)
# tensor(2.9487e-12, dtype=torch.float64)
# tensor(6.0804e-12, dtype=torch.float64)
# tensor(1.2413e-11, dtype=torch.float64)
# tensor(2.5090e-11, dtype=torch.float64)
# tensor(5.0206e-11, dtype=torch.float64)
# tensor(9.9468e-11, dtype=torch.float64)
# tensor(1.9510e-10, dtype=torch.float64)
# tensor(3.7888e-10, dtype=torch.float64)
# tensor(7.2844e-10, dtype=torch.float64)
# tensor(1.3866e-09, dtype=torch.float64)
# tensor(2.6131e-09, dtype=torch.float64)
# tensor(4.8755e-09, dtype=torch.float64)
# tensor(9.0062e-09, dtype=torch.float64)
# tensor(1.6471e-08, dtype=torch.float64)
# tensor(2.9823e-08, dtype=torch.float64)
# tensor(5.3463e-08, dtype=torch.float64)
# tensor(9.4886e-08, dtype=torch.float64)
# tensor(1.6673e-07, dtype=torch.float64)
# tensor(2.9005e-07, dtype=torch.float64)
# tensor(4.9957e-07, dtype=torch.float64)
# tensor(8.5187e-07, dtype=torch.float64)
# tensor(1.4382e-06, dtype=torch.float64)
# tensor(2.4038e-06, dtype=torch.float64)
# tensor(3.9779e-06, dtype=torch.float64)
# tensor(6.5172e-06, dtype=torch.float64)
# tensor(1.0571e-05, dtype=torch.float64)
# tensor(1.6976e-05, dtype=torch.float64)
# tensor(2.6991e-05, dtype=torch.float64)
# tensor(4.2487e-05, dtype=torch.float64)
# tensor(6.6214e-05, dtype=torch.float64)
# tensor(0.0001, dtype=torch.float64)
# tensor(0.0002, dtype=torch.float64)
# tensor(0.0002, dtype=torch.float64)
# tensor(0.0004, dtype=torch.float64)
# tensor(0.0005, dtype=torch.float64)
# tensor(0.0008, dtype=torch.float64)
# tensor(0.0011, dtype=torch.float64)
# tensor(0.0016, dtype=torch.float64)
# tensor(0.0023, dtype=torch.float64)
# tensor(0.0032, dtype=torch.float64)
# tensor(0.0045, dtype=torch.float64)
# tensor(0.0062, dtype=torch.float64)
# tensor(0.0085, dtype=torch.float64)
# tensor(0.0116, dtype=torch.float64)
# tensor(0.0155, dtype=torch.float64)
# tensor(0.0206, dtype=torch.float64)
# tensor(0.0271, dtype=torch.float64)
# tensor(0.0352, dtype=torch.float64)
# tensor(0.0454, dtype=torch.float64)
# tensor(0.0579, dtype=torch.float64)
# tensor(0.0732, dtype=torch.float64)
# tensor(0.0915, dtype=torch.float64)
# tensor(0.1133, dtype=torch.float64)
# tensor(0.1389, dtype=torch.float64)
# tensor(0.1686, dtype=torch.float64)
# tensor(0.2026, dtype=torch.float64)
# tensor(0.2410, dtype=torch.float64)
# tensor(0.2839, dtype=torch.float64)
# tensor(0.3310, dtype=torch.float64)
# tensor(0.3822, dtype=torch.float64)
# tensor(0.4368, dtype=torch.float64)
# tensor(0.4943, dtype=torch.float64)
# tensor(0.5539, dtype=torch.float64)
# tensor(0.6144, dtype=torch.float64)
# tensor(0.6747, dtype=torch.float64)
# tensor(0.7336, dtype=torch.float64)
# tensor(0.7897, dtype=torch.float64)
# tensor(0.8417, dtype=torch.float64)
# tensor(0.8881, dtype=torch.float64)
# tensor(0.9278, dtype=torch.float64)
# tensor(0.9595, dtype=torch.float64)
# tensor(0.9825, dtype=torch.float64)
# tensor(0.9961, dtype=torch.float64)
# tensor(0.9998, dtype=torch.float64)
# tensor(0.9935, dtype=torch.float64)
# tensor(0.9774, dtype=torch.float64)
# tensor(0.9520, dtype=torch.float64)
# tensor(0.9181, dtype=torch.float64)
# tensor(0.8765, dtype=torch.float64)
# tensor(0.8285, dtype=torch.float64)
# tensor(0.7754, dtype=torch.float64)
# tensor(0.7184, dtype=torch.float64)
# tensor(0.6590, dtype=torch.float64)
# tensor(0.5985, dtype=torch.float64)
# tensor(0.5381, dtype=torch.float64)
# tensor(0.4791, dtype=torch.float64)
# tensor(0.4222, dtype=torch.float64)
# tensor(0.3684, dtype=torch.float64)
# tensor(0.3183, dtype=torch.float64)
# tensor(0.2722, dtype=torch.float64)
# tensor(0.2305, dtype=torch.float64)
# tensor(0.1932, dtype=torch.float64)
# tensor(0.1604, dtype=torch.float64)
# tensor(0.1318, dtype=torch.float64)
# tensor(0.1072, dtype=torch.float64)
# tensor(0.0864, dtype=torch.float64)
# tensor(0.0689, dtype=torch.float64)
# tensor(0.0544, dtype=torch.float64)
# tensor(0.0425, dtype=torch.float64)
# tensor(0.0329, dtype=torch.float64)
# tensor(0.0252, dtype=torch.float64)
# tensor(0.0191, dtype=torch.float64)
# tensor(0.0144, dtype=torch.float64)
# tensor(0.0107, dtype=torch.float64)
# tensor(0.0079, dtype=torch.float64)
# tensor(0.0057, dtype=torch.float64)
# tensor(0.0041, dtype=torch.float64)
# tensor(0.0030, dtype=torch.float64)
# tensor(0.0021, dtype=torch.float64)
# tensor(0.0015, dtype=torch.float64)
# tensor(0.0010, dtype=torch.float64)
# tensor(0.0007, dtype=torch.float64)
# tensor(0.0005, dtype=torch.float64)
# tensor(0.0003, dtype=torch.float64)
# tensor(0.0002, dtype=torch.float64)
# tensor(0.0001, dtype=torch.float64)
# tensor(9.1285e-05, dtype=torch.float64)
# tensor(5.9008e-05, dtype=torch.float64)
# tensor(3.7764e-05, dtype=torch.float64)
# tensor(2.3928e-05, dtype=torch.float64)
# tensor(1.5010e-05, dtype=torch.float64)
# tensor(9.3225e-06, dtype=torch.float64)
# tensor(5.7323e-06, dtype=torch.float64)
# tensor(3.4897e-06, dtype=torch.float64)
# tensor(2.1033e-06, dtype=torch.float64)
# tensor(1.2551e-06, dtype=torch.float64)
# tensor(7.4148e-07, dtype=torch.float64)
# tensor(4.3369e-07, dtype=torch.float64)
# tensor(2.5114e-07, dtype=torch.float64)
# tensor(1.4399e-07, dtype=torch.float64)
# tensor(8.1729e-08, dtype=torch.float64)
# tensor(4.5929e-08, dtype=torch.float64)
# tensor(2.5554e-08, dtype=torch.float64)
# tensor(1.4076e-08, dtype=torch.float64)
# tensor(7.6765e-09, dtype=torch.float64)
# tensor(4.1448e-09, dtype=torch.float64)
# tensor(2.2157e-09, dtype=torch.float64)
# tensor(1.1726e-09, dtype=torch.float64)
# tensor(6.1442e-10, dtype=torch.float64)
# tensor(3.1874e-10, dtype=torch.float64)
# tensor(1.6371e-10, dtype=torch.float64)
# tensor(8.3242e-11, dtype=torch.float64)
# tensor(4.1907e-11, dtype=torch.float64)
# tensor(2.0887e-11, dtype=torch.float64)
# tensor(1.0307e-11, dtype=torch.float64)
# tensor(5.0355e-12, dtype=torch.float64)
# tensor(2.4356e-12, dtype=torch.float64)
# tensor(1.1664e-12, dtype=torch.float64)
# tensor(5.5299e-13, dtype=torch.float64)
# tensor(2.5957e-13, dtype=torch.float64)
# tensor(1.2063e-13, dtype=torch.float64)
# tensor(5.5502e-14, dtype=torch.float64)
# tensor(2.5282e-14, dtype=torch.float64)
# tensor(1.1402e-14, dtype=torch.float64)
# tensor(5.0911e-15, dtype=torch.float64)
# tensor(2.2506e-15, dtype=torch.float64)
# tensor(9.8499e-16, dtype=torch.float64)
# tensor(4.2680e-16, dtype=torch.float64)
# tensor(1.8310e-16, dtype=torch.float64)
# tensor(7.7766e-17, dtype=torch.float64)
# tensor(3.2700e-17, dtype=torch.float64)
# tensor(1.3614e-17, dtype=torch.float64)
# tensor(5.6112e-18, dtype=torch.float64)
# tensor(2.2898e-18, dtype=torch.float64)
# tensor(9.2511e-19, dtype=torch.float64)
# tensor(3.7004e-19, dtype=torch.float64)
# tensor(1.4654e-19, dtype=torch.float64)
# tensor(5.7454e-20, dtype=torch.float64)
# tensor(2.2302e-20, dtype=torch.float64)
# tensor(8.5708e-21, dtype=torch.float64)
# tensor(3.2611e-21, dtype=torch.float64)
# tensor(1.2284e-21, dtype=torch.float64)
# tensor(4.5815e-22, dtype=torch.float64)
# tensor(1.6917e-22, dtype=torch.float64)
# tensor(6.1841e-23, dtype=torch.float64)
# tensor(2.2382e-23, dtype=torch.float64)
# tensor(8.0201e-24, dtype=torch.float64)
# tensor(2.8452e-24, dtype=torch.float64)
# tensor(9.9933e-25, dtype=torch.float64)
# tensor(3.4750e-25, dtype=torch.float64)
# tensor(1.1964e-25, dtype=torch.float64)
# tensor(4.0779e-26, dtype=torch.float64)
# tensor(1.3761e-26, dtype=torch.float64)
# tensor(4.5976e-27, dtype=torch.float64)
# tensor(1.5208e-27, dtype=torch.float64)
# tensor(4.9804e-28, dtype=torch.float64)
# tensor(1.6148e-28, dtype=torch.float64)
# tensor(5.1835e-29, dtype=torch.float64)
# tensor(1.6473e-29, dtype=torch.float64)
# tensor(5.1833e-30, dtype=torch.float64)
# tensor(1.6147e-30, dtype=torch.float64)
# tensor(4.9799e-31, dtype=torch.float64)
# tensor(1.5206e-31, dtype=torch.float64)
# tensor(4.5969e-32, dtype=torch.float64)
# tensor(1.3758e-32, dtype=torch.float64)
# tensor(4.0769e-33, dtype=torch.float64)
# tensor(1.1961e-33, dtype=torch.float64)
# tensor(3.4740e-34, dtype=torch.float64)
# tensor(9.9900e-35, dtype=torch.float64)
# tensor(2.8442e-35, dtype=torch.float64)
# tensor(8.0169e-36, dtype=torch.float64)
# tensor(2.2372e-36, dtype=torch.float64)
# tensor(6.1812e-37, dtype=torch.float64)
# tensor(1.6908e-37, dtype=torch.float64)
# tensor(4.5790e-38, dtype=torch.float64)
# tensor(1.2277e-38, dtype=torch.float64)
# tensor(3.2591e-39, dtype=torch.float64)
# tensor(8.5653e-40, dtype=torch.float64)
# tensor(2.2287e-40, dtype=torch.float64)
# tensor(5.7413e-41, dtype=torch.float64)
# tensor(1.4643e-41, dtype=torch.float64)
# tensor(3.6975e-42, dtype=torch.float64)
# tensor(9.2436e-43, dtype=torch.float64)
# tensor(2.2879e-43, dtype=torch.float64)
# tensor(5.6063e-44, dtype=torch.float64)
# tensor(1.3601e-44, dtype=torch.float64)
# tensor(3.2670e-45, dtype=torch.float64)
# tensor(7.7690e-46, dtype=torch.float64)
# tensor(1.8291e-46, dtype=torch.float64)
# tensor(4.2636e-47, dtype=torch.float64)
# tensor(9.8393e-48, dtype=torch.float64)
# tensor(2.2481e-48, dtype=torch.float64)
# tensor(5.0853e-49, dtype=torch.float64)
# tensor(1.1389e-49, dtype=torch.float64)
# tensor(2.5252e-50, dtype=torch.float64)
# tensor(5.5433e-51, dtype=torch.float64)
# tensor(1.2048e-51, dtype=torch.float64)
# tensor(2.5923e-52, dtype=torch.float64)
# tensor(5.5225e-53, dtype=torch.float64)
# tensor(1.1648e-53, dtype=torch.float64)
# tensor(2.4322e-54, dtype=torch.float64)
# tensor(5.0283e-55, dtype=torch.float64)
# tensor(1.0292e-55, dtype=torch.float64)
# tensor(2.0856e-56, dtype=torch.float64)
# tensor(4.1842e-57, dtype=torch.float64)
# tensor(8.3111e-58, dtype=torch.float64)
# tensor(1.6344e-58, dtype=torch.float64)
# tensor(3.1822e-59, dtype=torch.float64)
# tensor(6.1339e-60, dtype=torch.float64)
# tensor(1.1706e-60, dtype=torch.float64)
# tensor(2.2118e-61, dtype=torch.float64)
# tensor(4.1374e-62, dtype=torch.float64)
# tensor(7.6626e-63, dtype=torch.float64)
# tensor(1.4050e-63, dtype=torch.float64)
# tensor(2.5506e-64, dtype=torch.float64)
# tensor(4.5841e-65, dtype=torch.float64)
# tensor(8.1569e-66, dtype=torch.float64)
# tensor(1.4370e-66, dtype=torch.float64)
# tensor(2.5064e-67, dtype=torch.float64)
# tensor(4.3280e-68, dtype=torch.float64)
# tensor(7.3993e-69, dtype=torch.float64)
# tensor(1.2524e-69, dtype=torch.float64)
# tensor(2.0988e-70, dtype=torch.float64)
# tensor(3.4821e-71, dtype=torch.float64)
# tensor(5.7196e-72, dtype=torch.float64)
# tensor(9.3015e-73, dtype=torch.float64)
# tensor(1.4976e-73, dtype=torch.float64)
# tensor(2.3873e-74, dtype=torch.float64)
# tensor(3.7675e-75, dtype=torch.float64)
# tensor(5.8867e-76, dtype=torch.float64)
# tensor(9.1064e-77, dtype=torch.float64)
# tensor(1.3947e-77, dtype=torch.float64)
# tensor(2.1148e-78, dtype=torch.float64)
# tensor(3.1747e-79, dtype=torch.float64)
# tensor(4.7185e-80, dtype=torch.float64)

# %%
for i in range(3, 10):
    show_landmarks(**ball_dataset[i])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-b5a76f4bc997> in <module>
#       1 for i in range(3, 10):
# ----> 2     show_landmarks(**ball_dataset[i])
#       3     plt.show()
#
# <ipython-input-11-6e46faee8f8f> in show_landmarks(image, target)
#       1 def show_landmarks(image, target):
#       2     """Show image with landmarks"""
# ----> 3     plt.imshow(image)
#       4     plt.show()
#       5     plt.imshow(target)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in set_data(self, A)
#     644         if not (self._A.ndim == 2
#     645                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 646             raise TypeError("Invalid dimensions for image data")
#     647
#     648         if self._A.ndim == 3:
#
# TypeError: Invalid dimensions for image data
